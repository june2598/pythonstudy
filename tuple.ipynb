# %% [markdown]
# #튜플 : 리스트의 불변객체

# %%
numbers = (1,2,3,4,5)
numbers.append(6)
numbers
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-1-3fdd56ff140e> in <cell line: 2>()
#       1 numbers = (1,2,3,4,5)
# ----> 2 numbers.append(6)
#       3 nembers
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
numbers = (1,2,3,4,5)
numbers.remove(3)
numbers
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-b11a3e75608d> in <cell line: 2>()
#       1 numbers = (1,2,3,4,5)
# ----> 2 numbers.remove(3)
#       3 numbers
#
# AttributeError: 'tuple' object has no attribute 'remove'

# %%
numbers = (1,2,3,4,5)
numbers.clear()
numbers
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-e9931dcf3e65> in <cell line: 2>()
#       1 numbers = (1,2,3,4,5)
# ----> 2 numbers.clear()
#       3 numbers
#
# AttributeError: 'tuple' object has no attribute 'clear'

# %%
numbers = (1,2,3,4,5)
numbers.insert(3,10)
numbers
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-d5bc689e409b> in <cell line: 2>()
#       1 numbers = (1,2,3,4,5)
# ----> 2 numbers.insert(3,10)
#       3 numbers
#
# AttributeError: 'tuple' object has no attribute 'insert'

# %%
numbers[2] = 10
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-ad3521c796b9> in <cell line: 1>()
# ----> 1 numbers[2] = 10
#
# TypeError: 'tuple' object does not support item assignment

# %%
numbers = (1,2,3,4,5)
idx = numbers.index(3)
print(idx)
print(max(numbers),min(numbers))
print(len(numbers))
# Out:
# 2
# 5 1
# 5

# %%
https://gall.dcinside.com/board/view/?id=dog&no=1040440
