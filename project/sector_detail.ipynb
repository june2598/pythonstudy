# %%
# 데이터 분석을 위한 패키지
import numpy as np
import pandas as pd

# %%
# 시각화 패키지
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import koreanize_matplotlib

# %%
# 모든 컬럼,행을 출력하도록 설정
pd.set_option('display.max_columns', None) # None으로 설정하면 모든 컬럼 출력
pd.set_option('display.max_rows', None) #None으로 설정하면 모든 행 출력

# %%
sector_detail = pd.read_csv('D:/kdt/project/crawling/sector_info_df_2024-12-18.csv')

# %%
sector_detail
# Out:
#     업종코드           업종명     전일비    전체   상승   보합   하락 등락그래프
# 0    307          전자제품  +5.29%    19   12    2    5   85%
# 1    273           자동차  +5.15%    15   11    1    3   83%
# 2    298      가정용기기와용품  +3.24%    20   10    1    9   52%
# 3    326     항공화물운송과물류  +3.18%    14   10    1    3   51%
# 4    270         자동차부품  +2.71%   152  111   13   28   43%
# 5    301            은행  +2.53%    11    9    0    2   41%
# 6    292           핸드셋  +2.44%    64   39    6   19   39%
# 7    321            증권  +2.42%    38   30    4    4   39%
# 8    327       디스플레이패널  +2.13%     4    3    1    0   34%
# 9    299            기계  +1.97%   101   56   11   34   31%
# 10   305           항공사  +1.82%     9    6    3    0   29%
# 11   285     방송과엔터테인먼트  +1.79%    57   34    8   15   29%
# 12   339    다각화된소비자서비스  +1.53%     1    1    0    0   24%
# 13   261            제약  +1.51%   182   95   16   71   24%
# 14   272            화학  +1.44%   121   84    7   30   23%
# 15   330          생명보험  +1.38%     4    3    1    0   22%
# 16   282       전자장비와기기  +1.35%   108   56   15   37   21%
# 17   315          손해보험  +1.34%    11    8    1    2   21%
# 18   294          통신장비  +1.28%    51   26    5   20   20%
# 19   304            철강  +1.25%    57   31    3   23   20%
# 20   300    양방향미디어와서비스  +1.25%    17    7    2    8   20%
# 21   290         교육서비스  +1.22%    23   13    3    7   19%
# 22   264      백화점과일반상점  +1.19%    15   11    1    3   19%
# 23   297          가정용품  +1.17%    11    7    3    1   18%
# 24   302    식품과기본식료품소매  +1.10%     8    6    0    2   17%
# 25   265          판매업체  +1.08%    10    7    1    2   17%
# 26   291            조선  +0.93%    24   17    1    6   15%
# 27   269    디스플레이장비및부품  +0.91%    77   46    6   25   14%
# 28   278     반도체와반도체장비  +0.89%   160   99   11   50   14%
# 29   279            건설  +0.89%    80   44    9   27   14%
# 30   289          건축자재  +0.80%    52   35    2   15   12%
# 31   333       무선통신서비스  +0.78%     3    3    0    0   12%
# 32   317    호텔,레스토랑,레저  +0.78%    19   13    2    4   12%
# 33   324     상업서비스와공급품  +0.76%    31   15    4   12   12%
# 34   283          전기제품  +0.75%    72   43    9   20   12%
# 35   267         IT서비스  +0.74%   101   44    6   51   12%
# 36   331        복합유틸리티  +0.73%     1    1    0    0   11%
# 37   325        전기유틸리티  +0.71%     5    3    1    1   11%
# 38   320          건축제품  +0.68%    13    7    1    5   11%
# 39   316    건강관리업체및서비스  +0.66%    12    5    1    6   10%
# 40   293      컴퓨터와주변기기  +0.65%    23   12    4    7   10%
# 41   276          복합기업  +0.64%    25   12    2   11   10%
# 42   334     무역회사와판매업체  +0.60%     5    3    0    2    9%
# 43   336     다각화된통신서비스  +0.58%     4    3    0    1    9%
# 44   274  섬유,의류,신발,호화품  +0.56%    84   50    6   28    9%
# 45   332           문구류  +0.45%     1    1    0    0    7%
# 46   296         운송인프라  +0.38%    10    7    2    1    6%
# 47   328          전문소매  +0.31%     6    2    2    2    5%
# 48   275            담배  +0.27%     1    1    0    0    4%
# 49   268            식품  +0.20%    89   56    3   30    3%
# 50    25            기타  +0.18%  1340  677  149  514    2%
# 51   280           부동산  +0.17%    28   15    2   11    2%
# 52   310            광고  +0.14%    16   10    0    6    2%
# 53   309            음료  +0.05%    16   10    1    5    0%
# 54   295     에너지장비및서비스  +0.02%    28   13    2   13    0%
# 55   314            출판  -0.04%     7    3    0    4    0%
# 56   313         석유와가스  -0.05%    21   12    2    7    0%
# 57   319          기타금융  -0.15%     5    2    1    2    2%
# 58   311           포장재  -0.17%    27   16    2    9    2%
# 59   318         종이와목재  -0.20%    18   10    4    4    3%
# 60   262    생명과학도구및서비스  -0.32%    41   12    8   21    5%
# 61   312        가스유틸리티  -0.33%    12    8    0    4    5%
# 62   271      레저용장비와제품  -0.34%    13    5    1    7    5%
# 63   323           해운사  -0.38%    11    5    3    3    6%
# 64   329       도로와철도운송  -0.44%     7    3    0    4    7%
# 65   266           화장품  -0.47%    65   28    7   30    7%
# 66   284       우주항공과국방  -0.62%    28   13    5   10   10%
# 67   281     건강관리장비와용품  -0.72%    93   31   15   47   11%
# 68   277          창업투자  -0.88%   120   47   36   37   14%
# 69   337            카드  -0.98%     1    0    0    1   15%
# 70   338       사무용전자제품  -1.06%     1    0    0    1   17%
# 71   263      게임엔터테인먼트  -1.38%    36   14    3   19   22%
# 72   286          생물공학  -1.43%    61   20    6   35   23%
# 73   303            가구  -1.56%    12    5    0    7   25%
# 74   287         소프트웨어  -2.08%    76   28    7   41   33%
# 75   306          전기장비  -2.41%    31   12    3   16   39%
# 76   308    인터넷과카탈로그소매  -2.54%     7    2    1    4   41%
# 77   322          비철금속  -2.86%    43   27    1   15   46%
# 78   288        건강관리기술  -6.16%    12    4    0    8  100%

# %%
code = sector_detail[sector_detail['업종명'] == '전자제품']['업종코드'].values[0]
code
# Out:
# 307

# %%
sector_detail.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 79 entries, 0 to 78
# Data columns (total 8 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   업종코드    79 non-null     int64
#  1   업종명     79 non-null     object
#  2   전일비     79 non-null     object
#  3   전체      79 non-null     int64
#  4   상승      79 non-null     int64
#  5   보합      79 non-null     int64
#  6   하락      79 non-null     int64
#  7   등락그래프   79 non-null     object
# dtypes: int64(5), object(3)
# memory usage: 5.1+ KB
