# %%
# 데이터 분석을 위한 패키지
import numpy as np
import pandas as pd

# %%
# 모든 컬럼,행을 출력하도록 설정
pd.set_option('display.max_columns', None) # None으로 설정하면 모든 컬럼 출력
pd.set_option('display.max_rows', None) #None으로 설정하면 모든 행 출력

# %%
import FinanceDataReader as fdr

# %%
df = fdr.DataReader('KS11')

# %%
df.head()
# Out:
#               Open    High     Low   Close     Volume  Change  UpDown   Comp  \
# Date
# 2001-06-11  612.46  615.41  607.20  608.23  340123834 -0.0218       2 -13.55
# 2001-06-12  605.36  611.88  603.91  607.15  319877548 -0.0018       2  -1.08
# 2001-06-13  611.79  614.05  607.48  614.05  392415108  0.0114       1   6.90
# 2001-06-14  612.96  623.37  610.36  613.75  420520519 -0.0005       2  -0.30
# 2001-06-15  609.54  618.96  604.37  618.96  375830101  0.0085       1   5.21
#
#                    Amount           MarCap
# Date
# 2001-06-11  1711354887650  213769808029580
# 2001-06-12  1579309434050  213407866089170
# 2001-06-13  1882785913600  215722300556140
# 2001-06-14  2138122210150  215864633350565
# 2001-06-15  1984248114150  217830955673590

# %%
stocks = fdr.StockListing('KOSPI')

# %%
stocks.head(10)
# Out:
#      Code        ISU_CD      Name Market Dept   Close ChangeCode  Changes  \
# 0  005930  KR7005930003      삼성전자  KOSPI        53700          2    -1200
# 1  000660  KR7000660001    SK하이닉스  KOSPI       174600          2    -8900
# 2  373220  KR7373220003  LG에너지솔루션  KOSPI       371500          2   -10000
# 3  207940  KR7207940008  삼성바이오로직스  KOSPI       975000          2    -5000
# 4  005380  KR7005380001       현대차  KOSPI       213000          2    -3500
# 5  068270  KR7068270008      셀트리온  KOSPI       195100          2    -4100
# 6  000270  KR7000270009        기아  KOSPI        99600          2    -2200
# 7  005935  KR7005931001     삼성전자우  KOSPI        44250          2    -1050
# 8  105560  KR7105560007      KB금융  KOSPI        85700          2    -1500
# 9  035420  KR7035420009     NAVER  KOSPI       209500          2    -3000
#
#    ChagesRatio    Open    High     Low   Volume        Amount  \
# 0        -2.19   53500   53800   53500  2412581  129336199900
# 1        -4.85  173900  174700  173000   902311  156795443700
# 2        -2.62  373500  374000  368000    28356   10536228000
# 3        -0.51  965000  980000  962000     3238    3140859000
# 4        -1.62  213000  213500  212000    46519    9900284500
# 5        -2.06  194100  196500  194100    67442   13160008500
# 6        -2.16  100000  100300   99500   175971   17577430100
# 7        -2.32   44300   44600   44250   106141    4706909400
# 8        -1.72   85600   86200   85100   140282   12024852700
# 9        -1.41  208500  211000  207500    96460   20149258000
#
#             Marcap      Stocks MarketId
# 0  320577322935000  5969782550      STK
# 1  127109212929000   728002365      STK
# 2   86931000000000   234000000      STK
# 3   69394650000000    71174000      STK
# 4   44605648683000   209416191      STK
# 5   42352025885400   217078554      STK
# 6   39608194147200   397672632      STK
# 7   36412736475000   822886700      STK
# 8   33725385851100   393528423      STK
# 9   33192553176000   158437008      STK
