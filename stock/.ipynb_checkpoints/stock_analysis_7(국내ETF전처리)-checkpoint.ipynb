# %%
# 데이터 분석을 위한 패키지
import numpy as np
import pandas as pd

# %%
# 시각화 패키지
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import koreanize_matplotlib

# %%
# 모든 컬럼,행을 출력하도록 설정
pd.set_option('display.max_columns', None) # None으로 설정하면 모든 컬럼 출력
pd.set_option('display.max_rows', 50) #None으로 설정하면 모든 행 출력

# %%
pd.options.display.float_format = '{:,.2f}'.format

# %%
df_etfs = pd.read_csv('etf_2024-12-12.csv')

# %%
df_etfs.shape
# Out:
# (931, 12)

# %%
df_etfs.head()
# Out:
#    Symbol  Category                 Name    Price  RiseFall  Change  \
# 0  459580         6    KODEX CD금리액티브(합성)  1056890         2     290
# 1  357870         6  TIGER CD금리투자KIS(합성)    55390         2      15
# 2  360750         4       TIGER 미국S&P500    21675         2     125
# 3   69500         1            KODEX 200    32670         2     165
# 4  423160         6  KODEX KOFR금리액티브(합성)   108910         2      10
#
#    ChangeRate          NAV  EarningRate   Volume  Amount  MarCap
# 0        0.03 1,056,695.00         0.85   140839  148850   93245
# 1        0.03    55,390.00         0.84    60199    3334   68912
# 2        0.58    21,705.00        18.21  2224994   48163   62576
# 3        0.51    32,676.00        -3.06  2969315   97172   55621
# 4        0.01   108,900.00         0.84    19928    2170   44454

# %%
df_etfs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 931 entries, 0 to 930
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Symbol       931 non-null    int64
#  1   Category     931 non-null    int64
#  2   Name         931 non-null    object
#  3   Price        931 non-null    int64
#  4   RiseFall     931 non-null    int64
#  5   Change       931 non-null    int64
#  6   ChangeRate   931 non-null    float64
#  7   NAV          931 non-null    float64
#  8   EarningRate  875 non-null    float64
#  9   Volume       931 non-null    int64
#  10  Amount       931 non-null    int64
#  11  MarCap       931 non-null    int64
# dtypes: float64(3), int64(8), object(1)
# memory usage: 87.4+ KB

# %%
# 거래량 상위 10개
df_etfs.sort_values('Volume', ascending=False).head(10)
# Out:
#      Symbol  Category               Name  Price  RiseFall  Change  ChangeRate  \
# 30   252670         3   KODEX 200선물인버스2X   2490         5     -25       -0.99
# 20   233740         3   KODEX 코스닥150레버리지   6915         2     135        1.99
# 139  251340         3  KODEX 코스닥150선물인버스   4105         5     -40       -0.97
# 12   122630         3         KODEX 레버리지  14500         2     150        1.05
# 62   114800         3          KODEX 인버스   4700         5     -25       -0.53
# 153  462330         2   KODEX 2차전지산업레버리지   1464         5     -10       -0.68
# 28   229200         1       KODEX 코스닥150  11475         2     130        1.15
# 29   148020         1           RISE 200  32915         2     160        0.49
# 3     69500         1          KODEX 200  32670         2     165        0.51
# 150  487240         2     KODEX AI전력핵심설비   9085         2      70        0.78
#
#           NAV  EarningRate    Volume  Amount  MarCap
# 30   2,491.00         5.67  48042824  119339   11334
# 20   6,958.00       -10.73  26068155  181038   17868
# 139  4,114.00         2.73  23841857   97671    2167
# 12  14,556.00        -8.16  12598127  183165   24157
# 62   4,704.00         3.73   6689448   31432    5593
# 153  1,474.00       -36.19   5877724    8632    1959
# 28  11,515.00        -3.82   4656817   53541   12209
# 29  32,910.00        -3.03   3221891  106094   11389
# 3   32,676.00        -3.06   2969315   97172   55621
# 150  9,131.00        17.46   2755149   25094    1962

# %%
# 파생열 추가 CategoryName
df_etfs['CategoryName'] = df_etfs['Category']

# %%
# 파생열 추가 CategoryName
df_etfs['CategoryName'] = df_etfs['Category']

# Category코드를 코드명으로 변경
# 1. 국내 시장지수 2. 국내 업종/테마 3. 국내파생 4. 해외주식 5. 원자재 6. 채권 7. 기타
category_decode = ['국내 시장지수','국내 업종/테마' ,'국내파생' ,'해외주식','원자재','채권','기타']
df_etfs['CategoryName'] = df_etfs['CategoryName'].replace([i+1 for i in range(7)],category_decode)

# %%
df_etfs.head(5)
# Out:
#    Symbol  Category                 Name    Price  RiseFall  Change  \
# 0  459580         6    KODEX CD금리액티브(합성)  1056890         2     290
# 1  357870         6  TIGER CD금리투자KIS(합성)    55390         2      15
# 2  360750         4       TIGER 미국S&P500    21675         2     125
# 3   69500         1            KODEX 200    32670         2     165
# 4  423160         6  KODEX KOFR금리액티브(합성)   108910         2      10
#
#    ChangeRate          NAV  EarningRate   Volume  Amount  MarCap CategoryName
# 0        0.03 1,056,695.00         0.85   140839  148850   93245           채권
# 1        0.03    55,390.00         0.84    60199    3334   68912           채권
# 2        0.58    21,705.00        18.21  2224994   48163   62576         해외주식
# 3        0.51    32,676.00        -3.06  2969315   97172   55621      국내 시장지수
# 4        0.01   108,900.00         0.84    19928    2170   44454           채권

# %%
df_etfs.columns.tolist()
# Out:
# ['Symbol',
#  'Category',
#  'Name',
#  'Price',
#  'RiseFall',
#  'Change',
#  'ChangeRate',
#  'NAV',
#  'EarningRate',
#  'Volume',
#  'Amount',
#  'MarCap',
#  'CategoryName']

# %%
columns = ['Symbol',
 'Category',
 'CategoryName',
 'Name',
 'Price',
 'RiseFall',
 'Change',
 'ChangeRate',
 'NAV',
 'EarningRate',
 'Volume',
 'Amount',
 'MarCap'
 ]

# %%
df_etfs
# Out:
#      Symbol  Category CategoryName                   Name    Price  RiseFall  \
# 0    459580         6           채권      KODEX CD금리액티브(합성)  1056890         2
# 1    357870         6           채권    TIGER CD금리투자KIS(합성)    55390         2
# 2    360750         4         해외주식         TIGER 미국S&P500    21675         2
# 3     69500         1      국내 시장지수              KODEX 200    32670         2
# 4    423160         6           채권    KODEX KOFR금리액티브(합성)   108910         2
# ..      ...       ...          ...                    ...      ...       ...
# 926  412560         2     국내 업종/테마         TIGER BBIG레버리지     2045         2
# 927  407310         1      국내 시장지수       HANARO 200 TOP10     7920         2
# 928  227550         2     국내 업종/테마          TIGER 200 산업재     6460         3
# 929  429990         7           기타  SOL 한국형글로벌플랫폼&메타버스액티브    16925         2
# 930  427110         2     국내 업종/테마            RISE 창업투자회사     6590         2
#
#      Change  ChangeRate          NAV  EarningRate   Volume  Amount  MarCap
# 0       290        0.03 1,056,695.00         0.85   140839  148850   93245
# 1        15        0.03    55,390.00         0.84    60199    3334   68912
# 2       125        0.58    21,705.00        18.21  2224994   48163   62576
# 3       165        0.51    32,676.00        -3.06  2969315   97172   55621
# 4        10        0.01   108,900.00         0.84    19928    2170   44454
# ..      ...         ...          ...          ...      ...     ...     ...
# 926      35        1.74     2,025.00         1.31      207       0      16
# 927      75        0.96     7,906.00        -2.43      833       6      16
# 928       0        0.00     6,536.00        -1.75        0       0      16
# 929     325        1.96    16,929.00        31.59        7       0      10
# 930       5        0.08     6,584.00        13.73     1003       6       9
#
# [931 rows x 13 columns]

# %% [markdown]
# ### 파생열 추가하기

# %% [markdown]
# #### 1) 카테고리명

# %%
columns = ['Symbol','Category','CategoryName','Name','Price','RiseFall','Change','ChangeRate','NAV','EarningRate','Volume','Amount','MarCap']

# case1) 열 재배치
df_etfs = df_etfs[columns]

# case2) reindex 메소드 사용
df_etfs = df_etfs.reindex(columns = columns)

# case3) insert('삽입위치','열이름', 값) 메소드
df_etfs.insert(2, 'CategoryName',df_etfs.pop('CategoryName'))
ef_etfs

# %%
df_etfs['Name']
# Out:
# 0          KODEX CD금리액티브(합성)
# 1        TIGER CD금리투자KIS(합성)
# 2             TIGER 미국S&P500
# 3                  KODEX 200
# 4        KODEX KOFR금리액티브(합성)
#                ...
# 926           TIGER BBIG레버리지
# 927         HANARO 200 TOP10
# 928            TIGER 200 산업재
# 929    SOL 한국형글로벌플랫폼&메타버스액티브
# 930              RISE 창업투자회사
# Name: Name, Length: 931, dtype: object

# %% [markdown]
# #### 2) 브랜드명

# %%
# df_etfs['Name'].str.split(' ').str[0]
df_etfs['Brand'] = df_etfs['Name'].str.split(' ').map(lambda list:list[0])

# %%
# 브랜드별 차지 비중 보기
# df['컬럼명'].value_counts() : 
df_etfs['Brand'].value_counts(normalize=True)*map(lambda x:f'{x * 100 : .2f}%')

# %%
# 상위 10개 pie 그래프
df_etfs['Brand'].value_counts(normalize=True).sort_values(ascending=False).head(10).plot(kind='pie', autopct='%1.1f%%')
plt.title('브랜드 비중')
# Out:
# Text(0.5, 1.0, '브랜드 비중')

# %% [markdown]
# 단기적인 시장전망에 따라 투자하세요.
#
# 레버리지/인버스에 대해 처음 가장 많이 오해하기 쉬운 것이 장기적으로 투자를 할 경우에도 2배,-1배의 수익률을 얻을 것이라고 기대하는 것입니다. 하지만 이것은 잘못된 생각입니다. 그 이유는 레버리지/인버스 의 운용 목적은 "투자 기간" 동안의 기초지수의 움직임의 2배/-1배가 아닌, 기초지수의 "일간변동률"의 2배 / -1배를 추적하기 때문입니다.
#
# 당일 수익률이 반영되면 원금이 변하기 때문에 다음 날 수익률이 반영이 되더라도 원금이 달라진 상태에서 반영이 되므로 누적 수익률은 예상과 다른 결과가 나오게 됩니다.
#
# 따라서 레버리지/인버스 투자의 경우 단기적인 시장전망에 따라 매매하는 것이 바람직한 투자전략이 될 수 있습니다.
# ( 시장의 투자기간이 길수록 누적수익률과 기초지수의 누적수익률의 격차가 발생할 가능성이 높습니다. )

# %%
# 인버스 상품 가져오기
df_etfs[df_etfs['Name'].str.contains('인버스')].head(3)
# Out:
#      Symbol  Category CategoryName               Name  Price  RiseFall  \
# 30   252670         3         국내파생   KODEX 200선물인버스2X   2490         5
# 62   114800         3         국내파생          KODEX 인버스   4700         5
# 139  251340         3         국내파생  KODEX 코스닥150선물인버스   4105         5
#
#      Change  ChangeRate      NAV  EarningRate    Volume  Amount  MarCap  Brand
# 30      -25       -0.99 2,491.00         5.67  48042824  119339   11334  KODEX
# 62      -25       -0.53 4,704.00         3.73   6689448   31432    5593  KODEX
# 139     -40       -0.97 4,114.00         2.73  23841857   97671    2167  KODEX

# %%
# 주가가 떨어질 경우 오히려 수익을 얻는 펀드를 인버스 펀드나 리버스 펀드라고 합니다.
# 인버스상품과, 아닌것의 비율 구하기
df_etfs['인버스'] = df_etfs['Name'].str.contains('인버스')
df_etfs['인버스'].value_counts(normalize=True)*100
# Out:
# 인버스
# False   95.27
# True     4.73
# Name: proportion, dtype: float64

# %%
# 레버리지 ETF 선물 등 파생상품에 투자해 지수보다 높은 수익을 추구하는 ETF
# 레버리지 상품과 아닌 상품의 비율 구하기
df_etfs['레버리지'] = df_etfs['Name'].str.contains('레버리지')
df_etfs['레버리지'].value_counts(normalize=True)*100
# Out:
# 레버리지
# False   94.84
# True     5.16
# Name: proportion, dtype: float64

# %%
# 헤지 상품과 아닌 상품의 비율 구하기
df_etfs['헤지'] = df_etfs['Name'].str.endswith('(H)')
df_etfs['헤지'].value_counts(normalize=True)*100
# Out:
# 헤지
# False   93.23
# True     6.77
# Name: proportion, dtype: float64

# %%
df_etfs.head()
# Out:
#    Symbol  Category CategoryName                 Name    Price  RiseFall  \
# 0  459580         6           채권    KODEX CD금리액티브(합성)  1056890         2
# 1  357870         6           채권  TIGER CD금리투자KIS(합성)    55390         2
# 2  360750         4         해외주식       TIGER 미국S&P500    21675         2
# 3   69500         1      국내 시장지수            KODEX 200    32670         2
# 4  423160         6           채권  KODEX KOFR금리액티브(합성)   108910         2
#
#    Change  ChangeRate          NAV  EarningRate   Volume  Amount  MarCap  \
# 0     290        0.03 1,056,695.00         0.85   140839  148850   93245
# 1      15        0.03    55,390.00         0.84    60199    3334   68912
# 2     125        0.58    21,705.00        18.21  2224994   48163   62576
# 3     165        0.51    32,676.00        -3.06  2969315   97172   55621
# 4      10        0.01   108,900.00         0.84    19928    2170   44454
#
#    Brand    인버스   레버리지     헤지
# 0  KODEX  False  False  False
# 1  TIGER  False  False  False
# 2  TIGER  False  False  False
# 3  KODEX  False  False  False
# 4  KODEX  False  False  False

# %%
df_etfs[df_etfs['레버리지']]

# %%
# 날짜는 파이썬 표준 라이브러리 datetime 사용
import datetime
# 오늘 날짜 가져오기
today = datetime.datetime.today()
today = today.strftime('%Y-%m-%d')
today
# Out:
# '2024-12-12'

# %%
file_name = f'etf_{today}.csv'
file_name
# Out:
# 'etf_2024-12-12.csv'

# %%
etfs.to_csv(file_name, index=False)
