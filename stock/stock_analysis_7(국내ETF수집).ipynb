# %%
# 데이터 분석을 위한 패키지
import numpy as np
import pandas as pd

# %%
# 시각화 패키지
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import koreanize_matplotlib

# %%
# 모든 컬럼,행을 출력하도록 설정
pd.set_option('display.max_columns', None) # None으로 설정하면 모든 컬럼 출력
pd.set_option('display.max_rows', 50) #None으로 설정하면 모든 행 출력

# %%
pd.options.display.float_format = '{:,.2f}'.format

# %%
import FinanceDataReader as fdr

# %%
etfs = fdr.StockListing('ETF/KR') # 한국 ETF 전 종목

# %%
etfs.shape
# Out:
# (930, 12)

# %%
etfs.head(2)
# Out:
#    Symbol  Category                 Name    Price RiseFall  Change  \
# 0  459580         6    KODEX CD금리액티브(합성)  1057560        2     300
# 1  357870         6  TIGER CD금리투자KIS(합성)    55425        2      15
#
#    ChangeRate          NAV  EarningRate  Volume  Amount  MarCap
# 0        0.03 1,057,346.00         0.84  289552  306219   95099
# 1        0.03    55,424.00         0.82  218161   12090   68508

# %% [markdown]
# Symbol : itemcode - ETF상품코드
# Category : etfTabCode - 상품범주(1. 국내 시장지수 2. 국내 업종/테마 3. 국내파생 4. 해외주식 5. 원자재 6. 채권 7. 기타)
# Name : itemname - 상품명
# Price : nowVal 현재가격
# RiseFall : (2-상승 3-변동없음 5-하락)
# Change : 전일비
# ChangeRate : 등락률
# NAV : 순자산가치
# EarningRate : 3개월 수익률
# Volume : 거래량
# Amount : 거래대금(백만)
# MarCap : 시가총액(억)

# %%
etfs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 930 entries, 0 to 929
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Symbol       930 non-null    object
#  1   Category     930 non-null    int64
#  2   Name         930 non-null    object
#  3   Price        930 non-null    int64
#  4   RiseFall     930 non-null    object
#  5   Change       930 non-null    int64
#  6   ChangeRate   930 non-null    float64
#  7   NAV          930 non-null    float64
#  8   EarningRate  870 non-null    float64
#  9   Volume       930 non-null    int64
#  10  Amount       930 non-null    int64
#  11  MarCap       930 non-null    int64
# dtypes: float64(3), int64(6), object(3)
# memory usage: 87.3+ KB

# %%
etfs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 930 entries, 0 to 929
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Symbol       930 non-null    object
#  1   Category     930 non-null    int64
#  2   Name         930 non-null    object
#  3   Price        930 non-null    int64
#  4   RiseFall     930 non-null    object
#  5   Change       930 non-null    int64
#  6   ChangeRate   930 non-null    float64
#  7   NAV          930 non-null    float64
#  8   EarningRate  870 non-null    float64
#  9   Volume       930 non-null    int64
#  10  Amount       930 non-null    int64
#  11  MarCap       930 non-null    int64
# dtypes: float64(3), int64(6), object(3)
# memory usage: 87.3+ KB

# %%
etfs['RiseFall'].value_counts()
# Out:
# RiseFall
# 5    742
# 2    169
# 3     19
# Name: count, dtype: int64

# %%
etfs.query('RiseFall == "3"')
# Out:
#      Symbol  Category                       Name   Price RiseFall  Change  \
# 106  473290         6  KODEX 26-12 회사채(AA-이상)액티브   10580        3       0
# 235  468820         6    WON 25-09 회사채(AA-이상)액티브   53830        3       0
# 243  498180         6          파워 종합채권(AA-이상)액티브  101400        3       0
# 368  099140         4                 KODEX 차이나H   19455        3       0
# 486  140700         2                   KODEX 보험    9660        3       0
# 541  487950         4          KODEX 대만테크고배당다우존스    9415        3       0
# 547  265690         4            ACE 러시아MSCI(합성)    8720        3       0
# 562  292770         6            KODEX 국채선물3년인버스   54600        3       0
# 620  453060         6       HANARO KOFR금리액티브(합성)  106465        3       0
# 632  449690         4            TIGER 한중반도체(합성)   14690        3       0
# 675  145850         2              TREX 펀더멘탈 200   37280        3       0
# 703  468370         6  KODEX iShares미국인플레이션국채액티브   11120        3       0
# 704  215620         2               HK S&P코리아로우볼   13055        3       0
# 753  337120         2                 KODEX 멀티팩터   11910        3       0
# 773  411860         4                KOSEF 독일DAX   13365        3       0
# 816  289250         2   TIGER MSCI KOREA ESG유니버설    9845        3       0
# 861  390950         6             HANARO 단기채권액티브  108725        3       0
# 873  244660         2              KODEX 퀄리티Plus    8305        3       0
# 890  147970         2                  TIGER 모멘텀   29650        3       0
#
#      ChangeRate        NAV  EarningRate  Volume  Amount  MarCap
# 106        0.00  10,586.00         1.15   27740     293    3139
# 235        0.00  53,837.00         0.98    1169      62    1059
# 243        0.00 100,908.00          NaN       0       0    1026
# 368        0.00  19,470.00        28.54    6774     131     418
# 486        0.00   9,672.00        -5.01   16787     160     222
# 541        0.00   9,457.00         3.46    6902      64     165
# 547        0.00      48.00         0.00       0       0     161
# 562        0.00  54,760.00         0.37       0       0     151
# 620        0.00 106,484.00         0.86       0       0     117
# 632        0.00  15,058.00        32.88       0       0     110
# 675        0.00  36,615.00        -4.84       0       0      93
# 703        0.00  11,122.00         5.50   22250     247      82
# 704        0.00  13,001.00        -1.21       0       0      82
# 753        0.00  11,807.00        -3.05       0       0      71
# 773        0.00  13,385.00        10.87     216       2      67
# 816        0.00   9,674.00        -3.44       0       0      59
# 861        0.00 108,765.00         0.78       0       0      45
# 873        0.00   8,295.00        -1.07       0       0      42
# 890        0.00  29,552.00         2.05       0       0      36

# %%
etfs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 930 entries, 0 to 929
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Symbol       930 non-null    object
#  1   Category     930 non-null    int64
#  2   Name         930 non-null    object
#  3   Price        930 non-null    int64
#  4   RiseFall     930 non-null    object
#  5   Change       930 non-null    int64
#  6   ChangeRate   930 non-null    float64
#  7   NAV          930 non-null    float64
#  8   EarningRate  870 non-null    float64
#  9   Volume       930 non-null    int64
#  10  Amount       930 non-null    int64
#  11  MarCap       930 non-null    int64
# dtypes: float64(3), int64(6), object(3)
# memory usage: 87.3+ KB

# %%
etfs.describe()
# Out:
#        Category        Price    Change  ChangeRate          NAV  EarningRate  \
# count    930.00       930.00    930.00      930.00       930.00       870.00
# mean       3.76    26,572.95   -226.96       -1.36    26,582.67         4.96
# std        1.84    71,217.37    362.49        1.65    71,211.26        14.69
# min        1.00     1,351.00 -4,165.00       -7.81        48.00       -42.49
# 25%        2.00     9,282.50   -315.00       -2.33     9,317.75        -3.47
# 50%        4.00    11,907.50   -170.00       -1.44    11,915.50         1.15
# 75%        6.00    18,733.75    -35.00       -0.29    18,706.50        10.01
# max        7.00 1,057,560.00    975.00        5.15 1,057,346.00        89.89
#
#               Volume     Amount    MarCap
# count         930.00     930.00    930.00
# mean      396,957.65   3,779.03  1,833.33
# std     4,250,965.52  21,250.80  6,266.58
# min             0.00       0.00      9.00
# 25%         1,079.50      15.00     83.25
# 50%         9,066.50     121.00    249.50
# 75%        59,678.50     910.25  1,089.00
# max   116,745,361.00 306,219.00 95,099.00

# %%
etfs.describe(include='O')
# Out:
#         Symbol               Name RiseFall
# count      930                930      930
# unique     930                930        3
# top     459580  KODEX CD금리액티브(합성)        5
# freq         1                  1      742

# %%
# 날짜는 파이썬 표준 라이브러리 datetime 사용
import datetime
# 오늘 날짜 가져오기
today = datetime.datetime.today()
today = today.strftime('%Y-%m-%d')
today
# Out:
# '2024-12-19'

# %%
file_name = f'etf_{today}.csv'
file_name
# Out:
# 'etf_2024-12-19.csv'

# %%
etfs.to_csv(file_name, index=False)

# %%
etfs.query('Category in (2,4)')
# Out:
#      Symbol  Category                   Name   Price RiseFall  Change  \
# 2    360750         4         TIGER 미국S&P500   21625        5     -50
# 5    133690         4         TIGER 미국나스닥100  138605        2     155
# 8    381170         4  TIGER 미국테크TOP10 INDXX   25160        5     -35
# 9    379800         4       KODEX 미국S&P500TR   19835        5     -40
# 11   381180         4    TIGER 미국필라델피아반도체나스닥   19215        2     275
# ..      ...       ...                    ...     ...      ...     ...
# 922  432850         4    HANARO 글로벌백신치료제MSCI   11175        5    -115
# 924  412560         2         TIGER BBIG레버리지    2080        2      60
# 926  407300         2          HANARO Fn골프테마    5250        3       0
# 927  227550         2          TIGER 200 산업재    6510        3       0
# 929  427110         2            RISE 창업투자회사    6480        5     -15
#
#      ChangeRate       NAV  EarningRate  Volume  Amount  MarCap
# 2         -0.23   21590.0      17.0672  407416    8807   62799
# 5          0.11  137854.0      20.5160   25622    3548   43855
# 8         -0.14   25014.0      27.5373  115096    2892   30657
# 9         -0.20   19807.0      17.1184  122103    2421   28642
# 11         1.45   18836.0       8.8630  187760    3601   27055
# ..          ...       ...          ...     ...     ...     ...
# 922       -1.02   11217.0      -6.5398     200       2      17
# 924        2.97    2066.0      -2.8847     137       0      17
# 926        0.00    5310.0      -7.2439       0       0      16
# 927        0.00    6589.0      -2.7633       0       0      16
# 929       -0.23    6556.0       8.7029       3       0       9
#
# [543 rows x 12 columns]
